# %%
internet = gt.collection.data["as-22july06"]
gt.graph_draw(internet, output="internet.png")
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f019979ed30, at 0x7f019473ff28>

# %%
dolph = gt.collection.data["dolphins"]
gt.graph_draw(dolph, output="dolphins.png")
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f019473f240, at 0x7f019473cba8>

# %%
neural = gt.collection.data["celegansneural"]
gt.graph_draw(neural, output="neural.png")
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f019473cf60, at 0x7f019473ca90>
